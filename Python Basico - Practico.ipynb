# %% [markdown]
# # Variables y tipos de datos
#
# Reglas para asignar nombres a las variables
#
# + El nombre de la variable debe ser único
# + Puede ser solo una palabra
# + Solo puede usar letras, números y el caracterr de subrayado (_)
# + No puede comenzar con un número
# + Los nombres de las variables que comienzan con un guión bajo se consideran "inútiles"

# %%
# Variable entera
x_entero = 29
# Variables decimales
x_decimal = 29.6
# Variable lógica
x_logica = True

# %%
# Trabajando con cadenas de caracteres
x_cadena = "Aprendiendo Python"

# %%
# Número complejo
x_complejo = 4 + 5j

# %%
# asignando multiples valores a variables distintas
x_puntos, x_nota, x_texto = 5, 3.2, "Hola"

# %%
# Asignando el mismo valor a distintas variables
x_nota1 = x_nota2 = x_nota3 = 6.5

# %%
x = 26
print(type(x))
x = True
print(type(x))
# Out:
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# # Entrada/salida estándar

# %% [markdown]
# Los programas serían de muy poca utilidad si no fueran capaces de interactuar con el usuario, es por ello que las funciones de entrada y salida estándar son útiles para establecer la comunicación.
#
# La entrada estándar se utiliza para pedir información al usuario y la salida estándar se utiliza para mostrar información por pantalla.

# %%
# Lectura desde teclado
x = input("Valor para x : ")
# Imprimir en la pantalla
print(x)
# Out:
# Valor para x : 286
# 286

# %% [markdown]
# ## Trabajando con cadenas de caracteres

# %%
# Uso de slice (este concepto se revisará con detalle más adelante)
c = "televisor"
print(c[:3])
print(c[3:])
print(c[0])
# Out:
# tel
# evisor
# t

# %%
c = "tengo mucho+sueño"
print(c.split("+"))
# Out:
# ['tengo mucho', 'sueño']

# %%
c = "paralelepipedo"
r = c.capitalize()
print(r)
r = c.upper()
print(r)
print(c)
# Out:
# Paralelepipedo
# PARALELEPIPEDO
# paralelepipedo

# %%
c = "soy una linda cadena"
print(c.isnumeric())
print(len(c))
c = "29"
print(c.isnumeric())
print(len(c))
# Out:
# False
# 20
# True
# 2

# %% [markdown]
# # Operadores aritméticos
#
# + Suma (+)
# + Resta (-)
# + Multiplicación (*)
# + División (/ y //)
# + Potencia (**)
# + Resto de una división (%)

# %%
x = 29
y = 6

# %%
z = x + y
print(z)
# Out:
# 35

# %%
z = x - y
print(z)
# Out:
# 23

# %%
z = x * y
print(z)
# Out:
# 174

# %%
z = x / y
print(z)
# Out:
# 4.833333333333333

# %%
z = x // y
print(z)
# Out:
# 4

# %%
a = 5
b = 3
z = a ** b
print(z)
# Out:
# 125

# %%
a = 23
b = 3
z = a % b
print(z)
# Out:
# 2

# %%
a = (50-5*6)/4
print(a)
# Out:
# 5.0

# %%
a = 3 * 3.75 / 1.5 
b = 7.0 / 2
print(a)
print(b)
# Out:
# 7.5
# 3.5

# %% [markdown]
# Python sigue las reglas habituales de precedencia y asociatividad; además, el operador potencia (**) es asociativo desde la derecha y más prioritario que el menos unario. Un ejemplo:

# %%
x = -2**2
print(x)
# Out:
# -4

# %%
r = 5
otro_r = r - 7
print(otro_r)
# Out:
# -5

# %% [markdown]
# ### Precedencia de operadores en Python

# %%
x = (3+5)/2 - 5
print(x)
# Out:
# -1.0

# %%
a = 20
b = 10
c = 15
d = 5
e = 0
e = (a + b) * c / d       #( 30 * 15 ) / 5
print("(a + b) * c / d ：",  e)

e = ((a + b) * c) / d     # (30 * 15 ) / 5
print("((a + b) * c) / d ：",  e)

e = (a + b) * (c / d);    # (30) * (15/5)
print("(a + b) * (c / d) ：",  e)

e = a + (b * c) / d;      #  20 + (150/5)
print ("a + (b * c) / d ：",  e)
# Out:
# (a + b) * c / d ： 90.0
# ((a + b) * c) / d ： 90.0
# (a + b) * (c / d) ： 90.0
# a + (b * c) / d ： 50.0

# %% [markdown]
# # Operadores de comparación y relacionales
#
# + Mayor que (>)
# + Menor que (<)
# + Mayor o igual que (>=)
# + Menor o igual que (<=)
# + Igualdad (==)
# + Distinto (!=)

# %%
29 > 25
# Out:
# True

# %%
x = 90
y = 12
x <= y
# Out:
# False

# %%
x == y
# Out:
# False

# %% [markdown]
# # Conectores lógicos
#
# Para realizar operaciones lógicas existen los operadores and, or y not. Los valores que devuelven son:
# + El operador **and** devuelve su primer operando si este es falso y el segundo en caso contrario.
# + El operador **or** devuelve su primero operando si este es cierto y el segundo en caso contrario.
# + El operador **not** devuelve False si su operando es cierto y True si es falso.

# %%
a = 12
b = 15
a >= 10 and a % 2 == 0
# Out:
# True

# %%
a <= 10 or a % 2 == 0
# Out:
# True

# %%
not a % 2 == 0
# Out:
# False

# %%
a % 2 != 0
# Out:
# False

# %%
b >= 15 and not a % 2 != 0
# Out:
# True

# %% [markdown]
# # Conversión de tipos de datos

# %%
a = 29
b = 2.6
z = a + b
print(z)
# Out:
# 31.6

# %%
a = "Python"
b = 29
z = a + str(b)
print(z)
# Out:
# Python29

# %%
a = "2" + "2"
b = int(a) + 7
print(a)
print(b)
# Out:
# 22
# 29

# %%
a = 4 + 2j
b = 2 - 3j
z = a + b
print(z)
# Out:
# (6-1j)

# %% [markdown]
# ---
#
#
# # *** A poner en práctica lo aprendido hasta ahora ... ***
#
# Abra el notebook asociado a las actividades y resuelva los ejercicios de la sección ***Ejercicios Variables, tipos de datos, operadores aritméticos y relacionales***.
#
#
#
# ---

# %% [markdown]
# # Colecciones
#
# Python tiene varios tipos de datos compuestos, usados para agrupar otros valores.

# %% [markdown]
# ## Listas
#
# El más versátil de todos los tipos de datos compuestos es la ***lista***, la cual puede ser escrita como una lista de valores separados por coma (ítems) entre corchetes. No es necesario que los ítems de una lista tengan todos el mismo tipo.

# %%
# Declara la lista
lista = []
print(lista)
# Agrega un elemento a la lista
lista.append(29)
print(lista)
# Agrega otro elemento a la lista
lista.append(25)
print(lista)
lista[0] = 32
print(lista)
lista.insert(0, 15)
print(lista)
# Out:
# []
# [29]
# [29, 25]
# [32, 25]
# [15, 32, 25]

# %%
lista.sort()
print(lista)
# Out:
# [25, 29]

# %%
# Agrega elementos de varios tipos de datos
lista.append("trabajando con listas")
print(lista)
lista.append(24.3)
print(lista)
# Qué pasará si se repiten los elementos
lista.append(24.3)
print(lista)
# Out:
# [15, 32, 25, 'trabajando con listas']
# [15, 32, 25, 'trabajando con listas', 24.3]
# [15, 32, 25, 'trabajando con listas', 24.3, 24.3]

# %%
print(lista.index(32))
print(lista.count(15))
print(lista.count(24.3))
# Out:
# 1
# 1
# 2

# %% [markdown]
# ## Acceso a los elementos de la lista

# %%
print(lista)
print(lista[0])
print(lista[4])
print(lista[-3])
# Out:
# [15, 32, 25, 'trabajando con listas', 24.3, 24.3]
# 15
# 24.3
# trabajando con listas

# %%
# Remueve elementos de la lista
lista.remove(24.3)
# Imprime contenido de la lista
print(lista)
# Out:
# [15, 32, 25, 'trabajando con listas']

# %%
# Inserta un elemento en un deterninado índice
lista.insert(3, "Nuevo")
# Imprime el contenido de la lista
print(lista)
# Out:
# [15, 32, 25, 'Nuevo', 'trabajando con listas']

# %%
lista = [12,34,29,6,15,9,30,3,4,1]
print(lista[0:2])
# Out:
# [12, 34]

# %% [markdown]
# ## Uso de slices
#
# Python tiene algunas propiedades especiales a la hora de tratar con listas. Se puede cortar una lista desde su inicio hasta determinado lugar, o desde determinado lugar hasta el final. A esto se le conoce como ***notación slice***.

# %%
lst_y = ['a','e','i','o','u',1,2,3,4,5] 
print(lst_y[:2])
print("2:", lst_y[-3]) 
print("3:", lst_y[-3:]) 
print("4:", lst_y[3:5])

print(lst_y[0:2], lst_y[:2])
print(lst_y[2:])
# Out:
# ['a', 'e']
# 2: 3
# 3: [3, 4, 5]
# 4: ['o', 'u']
# ['a', 'e'] ['a', 'e']
# ['i', 'o', 'u', 1, 2, 3, 4, 5]

# %% [markdown]
# ## Operaciones con listas

# %%
lista_a = [15,25,3,30]
lista_b = [3,4,5]
lista_c = lista_a + lista_b
print(lista_c)
# Out:
# [15, 25, 3, 30, 3, 4, 5]

# %%
lista_c[4] = lista_c[4] + 6
print(lista_c)
# Out:
# [15, 25, 3, 30, 9, 4, 5]

# %%
x = len(lista_c)
print(x)
# Out:
# 7

# %% [markdown]
# ---
#
#
# # *** A poner en práctica lo aprendido hasta ahora ... ***
#
# Abra el notebook asociado a las actividades y resuelva los ejercicios de la sección ***Ejercicios Listas***.
#
#
#
# ---

# %% [markdown]
# ## Tuplas
#
#
# Se sabe que las listas tienen propiedades como el indizado y las operaciones de seccionado. Estas son dos ejemplos de datos de tipo secuencia.
#
# Como Python es un lenguaje en evolución, otros datos de tipo secuencia pueden agregarse. Existe otro dato de tipo secuencia estándar: la tupla.
#
# Una tupla consiste de un número de valores separados por comas

# %%
t = ()
print(t.count(29))
tx = (15,25,30,3)
# Cuenta la cantidad de ocurrencias del elemento
print(tx.count(15))
print(tx.count(150))
# Retorna el índice del elemento indicado
print(tx.index(25))
# Out:
# 0
# 1
# 0
# 1

# %%
t = 29,
print(t)
print(type(t))
print(len(t))
# Out:
# (29,)
# <class 'tuple'>
# 1

# %%
tx = (15,12,4) 
ty = (25,15,8)
tx < ty
# Out:
# True

# %% [markdown]
# ---
#
#
# # *** A poner en práctica lo aprendido hasta ahora ... ***
#
# Abra el notebook asociado a las actividades y resuelva los ejercicios de la sección ***Ejercicios Tuplas***.
#
#
#
# ---

# %% [markdown]
# ## Conjuntos
#
# Python también incluye un tipo de dato para conjuntos. Un conjunto es una colección no ordenada y sin elementos repetidos. Los usos básicos de éstos incluyen verificación de pertenencia y eliminación de entradas duplicadas. Los conjuntos también soportan operaciones matemáticas como la unión, intersección, diferencia, y diferencia simétrica.

# %%
tc = {15,25,30,4}
print(tc)
tc = tc.union({33})
print(tc)
# Out:
# {25, 4, 30, 15}
# {33, 4, 25, 30, 15}

# %%
cx = set([25,15,4,30])
print(cx)
cx.discard(23)
print(cx)
cx.remove(4)
print(cx)
# Pruebe que sucede si intenta, usando el método remove con el argumento 40
print(len(cx))
# Out:
# {25, 4, 30, 15}
# {25, 4, 30, 15}
# {25, 30, 15}
# 3

# %%
"""
Respecto del método remove() la consideración que se debe tener es que si el 
elemento no existe marca error
"""
cx = {'a', "aire", "cocina", 26, 29, 1} 
print("cx antes : ", cx) 
cx.discard('b')
print("cx despues : ", cx)
# Out:
# cx antes :  {1, 'aire', 'a', 'cocina', 26, 29}
# cx despues :  {1, 'aire', 'a', 'cocina', 26, 29}

# %%
# Operaciones entre conjuntos
ca = {1,5,7,90.23}
cb = {2,45,68,12}
# Unión
cc = ca | cb
print("1:",cc)
# Intersección
cc = ca & cb
print("2:",cc)
ca = {2,4,6,8}
cb = {3,6,9}
cc = ca & cb
print("3:", cc)
print("4:", ca.intersection(cb))
# Subconjuntos
ca = {2,4,6,8,10}
cb = {6,4}
print("5:", cb.issubset(ca))
print("6:", ca.issubset(cb))
# Diferencia simétrica
print(ca.symmetric_difference(cb))
print(cb.symmetric_difference(ca))
# Profundizando en la diferencia simétrica
ca = {1, 2, 3, 4}
cb = {3, 4, 5, 6}
ca.symmetric_difference(cb)
# Out:
# 1: {1, 2, 68, 5, 7, 12, 45, 90.23}
# 2: set()
# 3: {6}
# 4: {6}
# 5: True
# 6: False
# {2, 8, 10}
# {2, 8, 10}
# {1, 2, 5, 6}

# %% [markdown]
# **Conjuntos disconexos**
#
#
#
# ---
#
# Se dice que un conjunto es disconexo respecto de otro si no comparten elementos entre sí, es decir, si su intersección es vacía.

# %%
# Conjuntos disconexos 
ca = {1, 2, 3}
cb = {3, 4, 5}
cc = {5, 6, 7}
print(ca.isdisjoint(cb)) # No son disconexos ya que comparten el elemento 3.
print(ca.isdisjoint(cc)) # Son disconexos.
# Out:
# False
# True

# %%
cx = {True, 'a', "aire", 29, 29 < 10, 20 % 2 == 0 } 
cx
# Out:
# {29, False, True, 'a', 'aire'}

# %%
cx = {296, 17, True, 3, 15, 29, 6}
print("cx: ", cx)
print("1: ", type(cx)) 
print("2: ", 29 in cx) 
print("3: ", 29 not in cx)
# Out:
# cx:  {True, 3, 6, 296, 15, 17, 29}
# 1:  <class 'set'>
# 2:  True
# 3:  False

# %% [markdown]
# **Conjuntos inmutables**
#
#
# ---
#
# *frozenset* es una implementación similar a set pero inmutable. Es decir, comparte todas las operaciones de conjuntos revisadas hasta el momento a excepción de aquellas que implican alterar sus elementos (add(), discard()). La diferencia es análoga a la existente entre una lista y una tupla.

# %%
ca = frozenset({1, 2, 3})
cb = frozenset({3, 4, 5})
print(ca & cb) # frozenset({3})
print(ca | cb) # frozenset({1, 2, 3, 4, 5})
print(ca.isdisjoint(cb)) # False
# Out:
# frozenset({3})
# frozenset({1, 2, 3, 4, 5})
# False

# %% [markdown]
# ---
#
#
# # *** A poner en práctica lo aprendido hasta ahora ... ***
#
# Abra el notebook asociado a las actividades y resuelva los ejercicios de la sección ***Ejercicios Conjuntos***.
#
#
#
# ---

# %% [markdown]
# ## Diccionarios

# %%
d_sueldos = {'Jaqueline': 980000, 'Santiago': 490000}
print(d_sueldos)
# Out:
# {'Jaqueline': 980000, 'Santiago': 490000}

# %%
d_sueldos['Santiago']
# Out:
# 490000

# %%
# Verificar si existe un elemento
'Guido' in d_sueldos
# Out:
# False

# %%
d_sueldos['Guido'] = 760000
print(d_sueldos)
# Out:
# {'Jaqueline': 980000, 'Santiago': 490000, 'Guido': 760000}

# %%
print(d_sueldos.keys())
print(d_sueldos.values())
# Out:
# dict_keys(['Jaqueline', 'Santiago', 'Guido'])
# dict_values([980000, 490000, 760000])

# %%
del d_sueldos['Santiago']
print(d_sueldos.keys())
# Out:
# dict_keys(['Jaqueline', 'Guido'])

# %%
d_amigos = dict([('Ariel', 41), ('Guido', 47), ('Gabriela', 49)])
print(d_amigos.keys())
d_amigos['Ariel'] = 54
print(d_amigos)
# Out:
# dict_keys(['Ariel', 'Guido', 'Gabriela'])
# {'Ariel': 54, 'Guido': 47, 'Gabriela': 49}

# %% [markdown]
# ---
#
#
# # *** A poner en práctica lo aprendido hasta ahora ... ***
#
# Abra el notebook asociado a las actividades y resuelva los ejercicios de la sección ***Ejercicios Diccionarios***.
#
#
#
# ---

# %% [markdown]
# # Estructuras de control

# %% [markdown]
# ## Condición

# %%
x = int(input("Ingrese valor : "))
if x == 2:
  print("Valor ingresado es 2")
# Out:
# Ingrese valor : 2
# Valor ingresado es 2

# %%
x = int(input("Ingrese valor : "))
if x % 2 == 0:
  print("Valor ingresado es par")
else:
  print("Valor ingresado es impar")
# Out:
# Ingrese valor : 29
# Valor ingresado es impar

# %%
x, y = 3, 3
if x != y:
  print("Variables distintas")
else:
  print("Variables iguales")
# Out:
# Variables iguales

# %%
x = int(input("Ingresa un entero, por favor: ")) 
if x < 0:
  print('Negativo')
elif x == 0:
  print('Cero')
elif x == 1:
  print('Unidad')
else:
  print('Mayor a 1')
# Out:
# Ingresa un entero, por favor: 29
# Mayor a 1

# %% [markdown]
# ---
#
#
# # *** A poner en práctica lo aprendido hasta ahora ... ***
#
# Abra el notebook asociado a las actividades y resuelva los ejercicios de la sección ***Ejercicios Condiciones***.
#
#
#
# ---

# %% [markdown]
# ## Repetición

# %% [markdown]
# ### Ciclo while

# %%
a, b = 1, 5
while a <= b:
  print(a)
  a = a + 1

# %% [markdown]
# ### Ciclo for

# %%
for a in range(2,11):
  if a % 2 == 0:
    print(a)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for a in range(2,11,2):
  print(a)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for a in range(2,11):
  if a % 2 != 0:
    continue
  print(a)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for a in range(7): 
  print(a)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
lista = ['Libro','Cine','TV']
for a in lista:
  print(a)
# Out:
# Libro
# Cine
# TV

# %%
lista = [15,13,7,5,4,135,29]
for valor in lista:
  print(valor)
  if valor % 2 == 0:
    break
# Out:
# 15
# 13
# 7
# 5
# 4

# %%
lista = [15,13,7,5,4,135,29]
for valor in lista:
  if valor % 2 == 0:
    pass
  else:
    print(valor)
# Out:
# 15
# 13
# 7
# 5
# A
# 135
# 29

# %%
lista = [15,13,7,5,4,135,29]
for valor in lista:
  if valor % 2 != 0:
    print(valor)
# Out:
# 15
# 13
# 7
# 5
# 135
# 29

# %%
lista = [15,13,7,5,4,135,29]
tx, ty = 0,0
for valor in lista:
  if valor % 2 == 0:
    tx = tx + 1
  else:
    ty = ty + 1
print(tx)
print(ty)
# Out:
# 1
# 6

# %% [markdown]
# ---
#
#
# # *** A poner en práctica lo aprendido hasta ahora ... ***
#
# Abra el notebook asociado a las actividades y resuelva los ejercicios de la sección ***Ejercicios Ciclos repetitivos***.
#
#
#
# ---
